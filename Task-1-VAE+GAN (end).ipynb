# %%
import numpy as np
import matplotlib.pyplot as plt
import time

from tensorflow.keras.datasets import mnist
from tensorflow import keras
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Reshape, Input, Lambda, BatchNormalization, Dropout
from tensorflow.keras.layers import Conv2D, LeakyReLU


(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train[y_train==5]
y_train = y_train[y_train==5]

BUFFER_SIZE = x_train.shape[0]
BATCH_SIZE = 100

length = BUFFER_SIZE // BATCH_SIZE * BATCH_SIZE
x_train = x_train[:length]
y_train = y_train[:length]
print(x_train.shape, y_train.shape)

# стандартизация входных данных
x_train = x_train / 255
x_test = x_test / 255

x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test  = np.reshape(x_test,  (len(x_test),  28, 28, 1))


train_dataset = tf.data.Dataset.from_tensor_slices(x_train).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)


# формирование сетей
hidden_dim = 2

def dropout_and_batch(x):
  return Dropout(0.3)(BatchNormalization()(x))

input_img = Input((28, 28, 1))
x = Flatten()(input_img)
x = Dense(256, activation='relu')(x)
x = dropout_and_batch(x)

z_mean = Dense(hidden_dim)(x)
z_log_var = Dense(hidden_dim)(x)

def noiser(args):
  global z_mean, z_log_var
  z_mean, z_log_var = args
  N = K.random_normal(shape=(BATCH_SIZE, hidden_dim), mean=0., stddev=1.0)
  return K.exp(z_log_var / 2) * N + z_mean

h = Lambda(noiser, output_shape=(hidden_dim,))([z_mean, z_log_var])

input_dec = Input(shape=(hidden_dim,))
d = Dense(256, activation='relu')(input_dec)
d = dropout_and_batch(d)
d = Dense(28*28, activation='sigmoid')(d)
decoded = Reshape((28, 28, 1))(d)

encoder = keras.Model(input_img, h, name='encoder')
decoder = keras.Model(input_dec, decoded, name='decoder')
generator = keras.Model(input_img, decoder(encoder(input_img)), name="generator")

# дискриминатор
discriminator = tf.keras.Sequential()
discriminator.add(Conv2D(64, (5, 5), strides=(2, 2), padding='same', input_shape=[28, 28, 1]))
discriminator.add(LeakyReLU())
discriminator.add(Dropout(0.3))

discriminator.add(Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
discriminator.add(LeakyReLU())
discriminator.add(Dropout(0.3))

discriminator.add(Flatten())
discriminator.add(Dense(1))


# потери
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def generator_loss(fake_output):
  loss = cross_entropy(tf.ones_like(fake_output), fake_output)
  kl_loss = -0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
  return (loss + kl_loss*0.1)


def discriminator_loss(real_output, fake_output):
  real_loss = cross_entropy(tf.ones_like(real_output), real_output)
  fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
  total_loss = real_loss + fake_loss
  return total_loss

generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)


# обучение
@tf.function
def train_step(images):
  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(images, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)

  gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
  gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

  return gen_loss, disc_loss


def train(dataset, epochs):
  history = []
  MAX_PRINT_LABEL = 10
  th = BUFFER_SIZE // (BATCH_SIZE*MAX_PRINT_LABEL)

  n_epoch = 1
  for epoch in range(epochs):
    print(f'{n_epoch}/{EPOCHS}: ', end='')

    start = time.time()
    n = 0

    gen_loss_epoch = 0
    for image_batch in dataset:
      gen_loss, disc_loss = train_step(image_batch)
      gen_loss_epoch += K.mean(gen_loss)
      if( n % th == 0): print('=', end='')
      n += 1

    history += [gen_loss_epoch/n]
    print(': '+str(history[-1]))
    print ('Время эпохи {} в {} секундах'.format(epoch + 1, time.time()-start))
    
    n_epoch += 1
  return history


# запуск процесса обучения
EPOCHS = 100

history = train(train_dataset, EPOCHS)


h = encoder.predict(x_test[:6000], batch_size=BATCH_SIZE)
plt.scatter(h[:, 0], h[:, 1])

plt.plot(history)
plt.grid(True)

# отображение результатов генерации
n = 2
total = 2*n+1

plt.figure(figsize=(total, total))

num = 1
for i in range(-n, n+1):
  for j in range(-n, n+1):
    ax = plt.subplot(total, total, num)
    num += 1
    img = decoder.predict(np.expand_dims([0.5*i/n, 0.5*j/n], axis=0))
    plt.imshow(img.squeeze(), cmap='gray')
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# Out:
# (5400, 28, 28) (5400,)
# 1/100: ===========: tf.Tensor(2.0803566, shape=(), dtype=float32)
# Время эпохи 1 в 3.802180528640747 секундах
# 2/100: ===========: tf.Tensor(5.2032137, shape=(), dtype=float32)
# Время эпохи 2 в 2.7513504028320312 секундах
# 3/100: ===========: tf.Tensor(9.2335615, shape=(), dtype=float32)
# Время эпохи 3 в 2.713937997817993 секундах
# 4/100: ===========: tf.Tensor(13.660319, shape=(), dtype=float32)
# Время эпохи 4 в 2.730696439743042 секундах
# 5/100: ===========: tf.Tensor(16.76963, shape=(), dtype=float32)
# Время эпохи 5 в 2.771328926086426 секундах
# 6/100: ===========: tf.Tensor(18.786495, shape=(), dtype=float32)
# Время эпохи 6 в 3.383225917816162 секундах
# 7/100: ===========: tf.Tensor(17.701738, shape=(), dtype=float32)
# Время эпохи 7 в 3.9949300289154053 секундах
# 8/100: ===========: tf.Tensor(15.409681, shape=(), dtype=float32)
# Время эпохи 8 в 3.988901376724243 секундах
# 9/100: ===========: tf.Tensor(13.13889, shape=(), dtype=float32)
# Время эпохи 9 в 3.9739928245544434 секундах
# 10/100: ===========: tf.Tensor(11.40144, shape=(), dtype=float32)
# Время эпохи 10 в 4.02849006652832 секундах
# 11/100: ===========: tf.Tensor(11.611561, shape=(), dtype=float32)
# Время эпохи 11 в 3.98518705368042 секундах
# 12/100: ===========: tf.Tensor(12.545014, shape=(), dtype=float32)
# Время эпохи 12 в 3.9836628437042236 секундах
# 13/100: ===========: tf.Tensor(12.699284, shape=(), dtype=float32)
# Время эпохи 13 в 3.9293248653411865 секундах
# 14/100: ===========: tf.Tensor(11.981419, shape=(), dtype=float32)
# Время эпохи 14 в 3.9654340744018555 секундах
# 15/100: ===========: tf.Tensor(10.810328, shape=(), dtype=float32)
# Время эпохи 15 в 4.0089874267578125 секундах
# 16/100: ===========: tf.Tensor(9.922532, shape=(), dtype=float32)
# Время эпохи 16 в 4.071244716644287 секундах
# 17/100: ===========: tf.Tensor(9.595052, shape=(), dtype=float32)
# Время эпохи 17 в 4.0165746212005615 секундах
# 18/100: ===========: tf.Tensor(8.788715, shape=(), dtype=float32)
# Время эпохи 18 в 2.832801580429077 секундах
# 19/100: ===========: tf.Tensor(8.613127, shape=(), dtype=float32)
# Время эпохи 19 в 2.6977832317352295 секундах
# 20/100: ===========: tf.Tensor(8.361099, shape=(), dtype=float32)
# Время эпохи 20 в 2.7000136375427246 секундах
# 21/100: ===========: tf.Tensor(7.9587884, shape=(), dtype=float32)
# Время эпохи 21 в 2.7272982597351074 секундах
# 22/100: ===========: tf.Tensor(7.856784, shape=(), dtype=float32)
# Время эпохи 22 в 2.7017905712127686 секундах
# 23/100: ===========: tf.Tensor(8.270872, shape=(), dtype=float32)
# Время эпохи 23 в 2.7167139053344727 секундах
# 24/100: ===========: tf.Tensor(8.102098, shape=(), dtype=float32)
# Время эпохи 24 в 2.714740514755249 секундах
# 25/100: ===========: tf.Tensor(8.175237, shape=(), dtype=float32)
# Время эпохи 25 в 2.7559053897857666 секундах
# 26/100: ===========: tf.Tensor(7.713143, shape=(), dtype=float32)
# Время эпохи 26 в 2.7361323833465576 секундах
# 27/100: ===========: tf.Tensor(7.5921755, shape=(), dtype=float32)
# Время эпохи 27 в 2.699092388153076 секундах
# 28/100: ===========: tf.Tensor(7.2413187, shape=(), dtype=float32)
# Время эпохи 28 в 2.6765971183776855 секундах
# 29/100: ===========: tf.Tensor(7.1815586, shape=(), dtype=float32)
# Время эпохи 29 в 2.6997013092041016 секундах
# 30/100: ===========: tf.Tensor(6.269334, shape=(), dtype=float32)
# Время эпохи 30 в 2.671970844268799 секундах
# 31/100: ===========: tf.Tensor(5.945393, shape=(), dtype=float32)
# Время эпохи 31 в 2.671325206756592 секундах
# 32/100: ===========: tf.Tensor(5.798756, shape=(), dtype=float32)
# Время эпохи 32 в 2.6570000648498535 секундах
# 33/100: ===========: tf.Tensor(6.144073, shape=(), dtype=float32)
# Время эпохи 33 в 2.6746768951416016 секундах
# 34/100: ===========: tf.Tensor(5.71524, shape=(), dtype=float32)
# Время эпохи 34 в 2.6593916416168213 секундах
# 35/100: ===========: tf.Tensor(5.3317904, shape=(), dtype=float32)
# Время эпохи 35 в 2.7014365196228027 секундах
# 36/100: ===========: tf.Tensor(5.258918, shape=(), dtype=float32)
# Время эпохи 36 в 2.695164680480957 секундах
# 37/100: ===========: tf.Tensor(5.014513, shape=(), dtype=float32)
# Время эпохи 37 в 2.70792555809021 секундах
# 38/100: ===========: tf.Tensor(4.815375, shape=(), dtype=float32)
# Время эпохи 38 в 2.7248940467834473 секундах
# 39/100: ===========: tf.Tensor(4.7515783, shape=(), dtype=float32)
# Время эпохи 39 в 2.7209689617156982 секундах
# 40/100: ===========: tf.Tensor(4.614574, shape=(), dtype=float32)
# Время эпохи 40 в 2.68157696723938 секундах
# 41/100: ===========: tf.Tensor(4.519347, shape=(), dtype=float32)
# Время эпохи 41 в 2.7323343753814697 секундах
# 42/100: ===========: tf.Tensor(4.440971, shape=(), dtype=float32)
# Время эпохи 42 в 2.734492301940918 секундах
# 43/100: ===========: tf.Tensor(4.580454, shape=(), dtype=float32)
# Время эпохи 43 в 2.727126359939575 секундах
# 44/100: ===========: tf.Tensor(4.7413993, shape=(), dtype=float32)
# Время эпохи 44 в 2.7231674194335938 секундах
# 45/100: ===========: tf.Tensor(4.3792768, shape=(), dtype=float32)
# Время эпохи 45 в 2.7271759510040283 секундах
# 46/100: ===========: tf.Tensor(4.287271, shape=(), dtype=float32)
# Время эпохи 46 в 2.760861396789551 секундах
# 47/100: ===========: tf.Tensor(3.9656768, shape=(), dtype=float32)
# Время эпохи 47 в 2.7390434741973877 секундах
# 48/100: ===========: tf.Tensor(3.791708, shape=(), dtype=float32)
# Время эпохи 48 в 2.7528111934661865 секундах
# 49/100: ===========: tf.Tensor(3.7002313, shape=(), dtype=float32)
# Время эпохи 49 в 2.7638375759124756 секундах
# 50/100: ===========: tf.Tensor(3.639093, shape=(), dtype=float32)
# Время эпохи 50 в 2.7516133785247803 секундах
# 51/100: ===========: tf.Tensor(3.665051, shape=(), dtype=float32)
# Время эпохи 51 в 2.7556185722351074 секундах
# 52/100: ===========: tf.Tensor(3.6524584, shape=(), dtype=float32)
# Время эпохи 52 в 2.7585718631744385 секундах
# 53/100: ===========: tf.Tensor(3.3992782, shape=(), dtype=float32)
# Время эпохи 53 в 2.736044406890869 секундах
# 54/100: ===========: tf.Tensor(3.0954008, shape=(), dtype=float32)
# Время эпохи 54 в 2.717020273208618 секундах
# 55/100: ===========: tf.Tensor(2.9446995, shape=(), dtype=float32)
# Время эпохи 55 в 2.6961119174957275 секундах
# 56/100: ===========: tf.Tensor(3.084566, shape=(), dtype=float32)
# Время эпохи 56 в 2.6813113689422607 секундах
# 57/100: ===========: tf.Tensor(2.9282715, shape=(), dtype=float32)
# Время эпохи 57 в 2.7098872661590576 секундах
# 58/100: ===========: tf.Tensor(3.0124562, shape=(), dtype=float32)
# Время эпохи 58 в 2.7176549434661865 секундах
# 59/100: ===========: tf.Tensor(3.0063212, shape=(), dtype=float32)
# Время эпохи 59 в 2.7335736751556396 секундах
# 60/100: ===========: tf.Tensor(3.0778656, shape=(), dtype=float32)
# Время эпохи 60 в 2.7569618225097656 секундах
# 61/100: ===========: tf.Tensor(3.0406897, shape=(), dtype=float32)
# Время эпохи 61 в 2.7135934829711914 секундах
# 62/100: ===========: tf.Tensor(3.0138063, shape=(), dtype=float32)
# Время эпохи 62 в 2.7069060802459717 секундах
# 63/100: ===========: tf.Tensor(2.9018238, shape=(), dtype=float32)
# Время эпохи 63 в 2.728644609451294 секундах
# 64/100: ===========: tf.Tensor(2.88176, shape=(), dtype=float32)
# Время эпохи 64 в 2.7110302448272705 секундах
# 65/100: ===========: tf.Tensor(3.0071392, shape=(), dtype=float32)
# Время эпохи 65 в 2.7056562900543213 секундах
# 66/100: ===========: tf.Tensor(2.9710693, shape=(), dtype=float32)
# Время эпохи 66 в 2.7043445110321045 секундах
# 67/100: ===========: tf.Tensor(3.0173502, shape=(), dtype=float32)
# Время эпохи 67 в 2.7163784503936768 секундах
# 68/100: ===========: tf.Tensor(2.8421133, shape=(), dtype=float32)
# Время эпохи 68 в 2.6854615211486816 секундах
# 69/100: ===========: tf.Tensor(2.9203699, shape=(), dtype=float32)
# Время эпохи 69 в 2.6929986476898193 секундах
# 70/100: ===========: tf.Tensor(2.8913424, shape=(), dtype=float32)
# Время эпохи 70 в 2.7094621658325195 секундах
# 71/100: ===========: tf.Tensor(3.0037951, shape=(), dtype=float32)
# Время эпохи 71 в 2.7073686122894287 секундах
# 72/100: ===========: tf.Tensor(2.960791, shape=(), dtype=float32)
# Время эпохи 72 в 2.7014012336730957 секундах
# 73/100: ===========: tf.Tensor(2.9802816, shape=(), dtype=float32)
# Время эпохи 73 в 2.7274577617645264 секундах
# 74/100: ===========: tf.Tensor(3.0032008, shape=(), dtype=float32)
# Время эпохи 74 в 2.7109992504119873 секундах
# 75/100: ===========: tf.Tensor(3.0397139, shape=(), dtype=float32)
# Время эпохи 75 в 2.7150092124938965 секундах
# 76/100: ===========: tf.Tensor(3.1009967, shape=(), dtype=float32)
# Время эпохи 76 в 2.7572543621063232 секундах
# 77/100: ===========: tf.Tensor(3.1321473, shape=(), dtype=float32)
# Время эпохи 77 в 2.739940881729126 секундах
# 78/100: ===========: tf.Tensor(3.2067347, shape=(), dtype=float32)
# Время эпохи 78 в 2.711564779281616 секундах
# 79/100: ===========: tf.Tensor(3.1901736, shape=(), dtype=float32)
# Время эпохи 79 в 2.7235097885131836 секундах
# 80/100: ===========: tf.Tensor(3.253533, shape=(), dtype=float32)
# Время эпохи 80 в 2.7359988689422607 секундах
# 81/100: ===========: tf.Tensor(3.2863235, shape=(), dtype=float32)
# Время эпохи 81 в 2.719083786010742 секундах
# 82/100: ===========: tf.Tensor(3.3122163, shape=(), dtype=float32)
# Время эпохи 82 в 2.713461399078369 секундах
# 83/100: ===========: tf.Tensor(3.4033477, shape=(), dtype=float32)
# Время эпохи 83 в 2.717806339263916 секундах
# 84/100: ===========: tf.Tensor(3.411266, shape=(), dtype=float32)
# Время эпохи 84 в 2.7409090995788574 секундах
# 85/100: ===========: tf.Tensor(3.3903525, shape=(), dtype=float32)
# Время эпохи 85 в 2.7187106609344482 секундах
# 86/100: ===========: tf.Tensor(3.365092, shape=(), dtype=float32)
# Время эпохи 86 в 2.7435755729675293 секундах
# 87/100: ===========: tf.Tensor(3.3346958, shape=(), dtype=float32)
# Время эпохи 87 в 2.6962220668792725 секундах
# 88/100: ===========: tf.Tensor(3.331046, shape=(), dtype=float32)
# Время эпохи 88 в 2.7288684844970703 секундах
# 89/100: ===========: tf.Tensor(3.3907568, shape=(), dtype=float32)
# Время эпохи 89 в 2.6885955333709717 секундах
# 90/100: ===========: tf.Tensor(3.4515393, shape=(), dtype=float32)
# Время эпохи 90 в 2.6843435764312744 секундах
# 91/100: ===========: tf.Tensor(3.5064087, shape=(), dtype=float32)
# Время эпохи 91 в 2.7227206230163574 секундах
# 92/100: ===========: tf.Tensor(3.5162046, shape=(), dtype=float32)
# Время эпохи 92 в 2.71225905418396 секундах
# 93/100: ===========: tf.Tensor(3.4400983, shape=(), dtype=float32)
# Время эпохи 93 в 2.698000192642212 секундах
# 94/100: ===========: tf.Tensor(3.4120483, shape=(), dtype=float32)
# Время эпохи 94 в 2.7005867958068848 секундах
# 95/100: ===========: tf.Tensor(3.4525423, shape=(), dtype=float32)
# Время эпохи 95 в 2.729013681411743 секундах
# 96/100: ===========: tf.Tensor(3.4475794, shape=(), dtype=float32)
# Время эпохи 96 в 2.7569990158081055 секундах
# 97/100: ===========: tf.Tensor(3.4217148, shape=(), dtype=float32)
# Время эпохи 97 в 2.757688283920288 секундах
# 98/100: ===========: tf.Tensor(3.435857, shape=(), dtype=float32)
# Время эпохи 98 в 2.716569423675537 секундах
# 99/100: ===========: tf.Tensor(3.407861, shape=(), dtype=float32)
# Время эпохи 99 в 2.726896047592163 секундах
# 100/100: ===========: tf.Tensor(3.4128714, shape=(), dtype=float32)
# Время эпохи 100 в 2.7138876914978027 секундах
# 60/60 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step

# %%
plt.plot(history)
